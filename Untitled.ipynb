# %%
import pandas as pd
import seaborn as sns 
import matplotlib.pyplot as plt
import pandas_datareader.data as web

from matplotlib.dates import DateFormatter

# %%
def get_stock(stock_name, start_date, end_date, fix_name=None): 
    output = web.DataReader(f"{stock_name}", "yahoo", start_date, end_date)

    if fix_name == None:
        fix_name = stock_name.lower()
    
    print(f"{fix_name}:\t{str(output.index.min())[:10]} - {str(output.index.max())[:10]}")
    return output[['Close']].rename(columns={'Close': f"{fix_name}"}) 


def execute_merge(stocks):
    min_date_dict = dict()

    for stock in stocks:
        stock_name = stock.columns[0]
        min_date_dict[stock_name] = stock.index.min()

    key_list = list(min_date_dict.keys())
    val_list = list(min_date_dict.values())

    standard_stock_idx = val_list.index(min(min_date_dict.values()))
    output = stocks[standard_stock_idx]

    stocks.pop(standard_stock_idx)

    for stock in stocks:    
        output = output.merge(stock, how='left', left_index=True, right_index=True)
    
    return output

# %%
start_date = "2014-01-01"
end_date = "2021-02-25"

skyy = get_stock("SKYY", start_date, end_date)
wugi = get_stock("WUGI", start_date, end_date)
xle = get_stock("XLE", start_date, end_date)
edoc = get_stock("EDOC", start_date, end_date)
ufo = get_stock("UFO", start_date, end_date)
snp = get_stock("^GSPC", start_date, end_date, 'snp')
syld = get_stock("SYLD", start_date, end_date)
krw = get_stock("KRW=X", start_date, end_date, 'krw')
fvx = get_stock("^FVX", start_date, end_date, 'fvx')
tnx = get_stock("^TNX", start_date, end_date, 'tnx')
# Out:
# skyy:	2013-12-31 - 2021-02-25
# wugi:	2020-03-31 - 2021-02-25
# xle:	2013-12-31 - 2021-02-25
# edoc:	2020-07-30 - 2021-02-25
# ufo:	2019-04-11 - 2021-02-25
# snp:	2013-12-31 - 2021-02-25
# syld:	2013-12-31 - 2021-02-25
# krw:	2013-12-31 - 2021-02-25
# fvx:	2013-12-31 - 2021-02-25
# tnx:	2013-12-31 - 2021-02-25

# %%
pwr = get_stock("PWR", start_date, end_date)
# Out:
# pwr:	2013-12-31 - 2021-02-25

# %%
stocks = [skyy, wugi, xle, edoc, ufo, snp, syld, krw, fvx, tnx, pwr]

output = execute_merge(stocks)
output
# Out:
#                   skyy       wugi        xle       edoc    ufo          snp  \
# Date
# 2013-12-31   26.549999        NaN  88.510002        NaN    NaN  1848.359985
# 2014-01-02   26.299999        NaN  87.250000        NaN    NaN  1831.979980
# 2014-01-03   26.420000        NaN  86.930000        NaN    NaN  1831.369995
# 2014-01-06   26.200001        NaN  87.050003        NaN    NaN  1826.770020
# 2014-01-07   26.510000        NaN  87.709999        NaN    NaN  1837.880005
# ...                ...        ...        ...        ...    ...          ...
# 2021-02-19  108.339996  59.880001  46.180000  22.120001  30.76  3906.709961
# 2021-02-22  104.220001  56.700001  47.779999  21.080000  30.26  3876.500000
# 2021-02-23  102.400002  56.020000  48.570000  20.870001  29.60  3881.370117
# 2021-02-24  103.959999  56.040001  50.290001  20.830000  30.48  3925.429932
# 2021-02-25   99.570000  53.682999  49.320000  20.160000  29.43  3829.340088
#
# ...

# %%
output.corr()
# Out:
#           skyy      wugi       xle      edoc       ufo       snp      syld  \
# skyy  1.000000  0.981959 -0.737556  0.973014  0.199376  0.978907  0.753052
# wugi  0.981959  1.000000  0.391572  0.986691  0.944911  0.983135  0.943787
# xle  -0.737556  0.391572  1.000000  0.733604  0.696773 -0.698344 -0.242418
# edoc  0.973014  0.986691  0.733604  1.000000  0.946859  0.946553  0.957429
# ufo   0.199376  0.944911  0.696773  0.946859  1.000000  0.426189  0.805372
# snp   0.978907  0.983135 -0.698344  0.946553  0.426189  1.000000  0.798209
# syld  0.753052  0.943787 -0.242418  0.957429  0.805372  0.798209  1.000000
# krw   0.256018 -0.899355 -0.679731 -0.754186 -0.597234  0.263722 -0.128436
# fvx  -0.281371  0.439627  0.569888  0.813918  0.579584 -0.186864  0.199326
# tnx  -0.491128  0.793307  0.772908  0.908163  0.673939 -0.432511  0.039772
# pwr   0.824010  0.949225 -0.429696  0.894160  0.358370  0.792358  0.763406
#
#            krw       fvx       tnx       pwr
# ...

# %% [markdown]
# palette
#
# 'Accent', 'Accent_r', 'Blues', 'Blues_r', 'BrBG', 'BrBG_r', 'BuGn', 'BuGn_r', 'BuPu', 'BuPu_r', 'CMRmap', 'CMRmap_r', 'Dark2', 'Dark2_r', 'GnBu', 'GnBu_r', 'Greens', 'Greens_r', 'Greys', 'Greys_r', 'OrRd', 'OrRd_r', 'Oranges', 'Oranges_r', 'PRGn', 'PRGn_r', 'Paired', 'Paired_r', 'Pastel1', 'Pastel1_r', 'Pastel2', 'Pastel2_r', 'PiYG', 'PiYG_r', 'PuBu', 'PuBuGn', 'PuBuGn_r', 'PuBu_r', 'PuOr', 'PuOr_r', 'PuRd', 'PuRd_r', 'Purples', 'Purples_r', 'RdBu', 'RdBu_r', 'RdGy', 'RdGy_r', 'RdPu', 'RdPu_r', 'RdYlBu', 'RdYlBu_r', 'RdYlGn', 'RdYlGn_r', 'Reds', 'Reds_r', 'Set1', 'Set1_r', 'Set2', 'Set2_r', 'Set3', 'Set3_r', 'Spectral', 'Spectral_r', 'Wistia', 'Wistia_r', 'YlGn', 'YlGnBu', 'YlGnBu_r', 'YlGn_r', 'YlOrBr', 'YlOrBr_r', 'YlOrRd', 'YlOrRd_r', 'afmhot', 'afmhot_r', 'autumn', 'autumn_r', 'binary', 'binary_r', 'bone', 'bone_r', 'brg', 'brg_r', 'bwr', 'bwr_r', 'cividis', 'cividis_r', 'cool', 'cool_r', 'coolwarm', 'coolwarm_r', 'copper', 'copper_r', 'crest', 'crest_r', 'cubehelix', 'cubehelix_r', 'flag', 'flag_r', 'flare', 'flare_r', 'gist_earth', 'gist_earth_r', 'gist_gray', 'gist_gray_r', 'gist_heat', 'gist_heat_r', 'gist_ncar', 'gist_ncar_r', 'gist_rainbow', 'gist_rainbow_r', 'gist_stern', 'gist_stern_r', 'gist_yarg', 'gist_yarg_r', 'gnuplot', 'gnuplot2', 'gnuplot2_r', 'gnuplot_r', 'gray', 'gray_r', 'hot', 'hot_r', 'hsv', 'hsv_r', 'icefire', 'icefire_r', 'inferno', 'inferno_r', 'jet', 'jet_r', 'magma', 'magma_r', 'mako', 'mako_r', 'nipy_spectral', 'nipy_spectral_r', 'ocean', 'ocean_r', 'pink', 'pink_r', 'plasma', 'plasma_r', 'prism', 'prism_r', 'rainbow', 'rainbow_r', 'rocket', 'rocket_r', 'seismic', 'seismic_r', 'spring', 'spring_r', 'summer', 'summer_r', 'tab10', 'tab10_r', 'tab20', 'tab20_r', 'tab20b', 'tab20b_r', 'tab20c', 'tab20c_r', 'terrain', 'terrain_r', 'turbo', 'turbo_r', 'twilight', 'twilight_r', 'twilight_shifted', 'twilight_shifted_r', 'viridis', 'viridis_r', 'vlag', 'vlag_r', 'winter', 'winter_r'

# %%
x = output.query("Date >= '2019-09-01' and Date <= '2023-01-01'")
sns.set(rc={'figure.figsize':(25, 8)})

sns.lineplot(data=x[['skyy', 'xle']], palette='twilight_r')
plt.legend(loc=2)

ax2 = plt.twinx()
sns.lineplot(data=x[['fvx', 'tnx']], palette='gist_stern_r', ax=ax2)
plt.legend(loc=1)

# %%
x.corr()
# Out:
#           skyy  wugi       xle  edoc       ufo       snp      syld       krw  \
# skyy  1.000000   NaN  0.162119   NaN  0.201490  0.802504  0.643037  0.456820
# wugi       NaN   NaN       NaN   NaN       NaN       NaN       NaN       NaN
# xle   0.162119   NaN  1.000000   NaN  0.542551 -0.283376  0.152560 -0.663800
# edoc       NaN   NaN       NaN   NaN       NaN       NaN       NaN       NaN
# ufo   0.201490   NaN  0.542551   NaN  1.000000 -0.011612  0.127403 -0.462575
# snp   0.802504   NaN -0.283376   NaN -0.011612  1.000000  0.760014  0.545130
# syld  0.643037   NaN  0.152560   NaN  0.127403  0.760014  1.000000 -0.012028
# krw   0.456820   NaN -0.663800   NaN -0.462575  0.545130 -0.012028  1.000000
# fvx  -0.346897   NaN  0.783517   NaN  0.426415 -0.696203 -0.118537 -0.850564
# tnx  -0.315836   NaN  0.800455   NaN  0.466816 -0.679155 -0.107257 -0.846325
# pwr   0.710496   NaN  0.070277   NaN  0.252527  0.793130  0.862547  0.136933
#
#            fvx       tnx       pwr
# ...
